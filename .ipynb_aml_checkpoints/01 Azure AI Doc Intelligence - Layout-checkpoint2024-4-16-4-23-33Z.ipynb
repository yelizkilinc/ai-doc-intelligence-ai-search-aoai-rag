# %% [markdown]
# # 01. Azure AI Document Intelligence - Layout Model

# %% [markdown]
# > https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/overview?view=doc-intel-4.0.0

# %% [markdown]
# ## Create a AI Document Intelligence resource
#
# To create a AI Document Intelligence resource in your Azure subscription:
# Please follow the steps as specified https://learn.microsoft.com/en-us/azure/ai-services/document-intelligence/create-document-intelligence-resource?view=doc-intel-4.0.0
#
#
# Get your newly created Document Intelligence service in the Azure portal and on the **Keys and Endpoint** page, copy the **Key1** and **Endpoint** values and paste them in the code cell below, replacing **YOUR_FORM_KEY** and **YOUR_FORM_ENDPOINT**.

# %% [markdown]
# Please ensure you have Python 3.10 version or above ie select **Python 3.10 - SDK v2** as kernal in AML. <br>
# For VS Code you can select Python **Python 3.10** above or try to set up virtual envi by following steps https://code.visualstudio.com/docs/python/environments

# %%
# install azure-ai-formrecognizer python library and restart the kernal after installation
# %pip install azure-ai-formrecognizer --upgrade --user
# Out:
# Collecting azure-ai-formrecognizer
#   Downloading azure_ai_formrecognizer-3.3.3-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.4/301.4 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: azure-core>=1.23.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (1.27.1)
# Requirement already satisfied: msrest>=0.6.21 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (0.7.1)
# Requirement already satisfied: azure-common>=1.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (1.1.28)
# Requirement already satisfied: typing-extensions>=4.0.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-ai-formrecognizer) (4.6.3)
# Requirement already satisfied: requests>=2.18.4 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from azure-core>=1.23.0->azure-ai-formrecognizer) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (2023.5.7)
# Requirement already satisfied: isodate>=0.6.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.18.4->azure-core>=1.23.0->azure-ai-formrecognizer) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.18.4->azure-core>=1.23.0->azure-ai-formrecognizer) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests>=2.18.4->azure-core>=1.23.0->azure-ai-formrecognizer) (1.26.16)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py310_sdkv2/lib/python3.10/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer) (3.2.2)
# Installing collected packages: azure-ai-formrecognizer
# Successfully installed azure-ai-formrecognizer-3.3.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## <mark>**A.Setting up AI Doc Intelligence endpoint and key**</mark>

# %%
import os
from azure.core.exceptions import ResourceNotFoundError
from azure.core.credentials import AzureKeyCredential
from azure.ai.formrecognizer import DocumentAnalysisClient, AnalyzeResult

# set `<your-endpoint>` and `<your-key>` variables with the values from the Azure portal
END_POINT = "XXXX"
END_POINT_KEY = "XXXX"

# create form recognizer client
form_recognizer_client = DocumentAnalysisClient(END_POINT, AzureKeyCredential(END_POINT_KEY))

# %%
print(END_POINT)
# Out:
# https://docintelligencroyallondon.cognitiveservices.azure.com/

# %% [markdown]
# ## B. Analysing the Layout Document

# %%
# sample document
layoutUrl = "XXXX"

# Start the document analysis using the Form Recognizer client
poller = form_recognizer_client.begin_analyze_document_from_url("prebuilt-layout",layoutUrl)
print(poller)

# Get the analysis result
result = poller.result()

# Extract document insights
# Check if the document contains handwritten content
if any([style.is_handwritten for style in result.styles]):
    print("Document contains handwritten content")
else:
    print("Document does not contain handwritten content")

# Iterate through each page in the document
for page in result.pages:
    print(f"----Analyzing layout from page #{page.page_number}----")
    print(
        f"Page has width: {page.width} and height: {page.height}, measured with unit: {page.unit}"
    )
    # Iterate through each line in the page
    for line_idx, line in enumerate(page.lines):
        words = line.get_words()
        #words = get_words(page, line)
        # Print information about each line
        print(
            f"...Line # {line_idx} has word count {len(words)} and text '{line.content}' "
            f"within bounding polygon '{line.polygon}'"
        )

        # Iterate through each word in the line and print its content and confidence
        for word in words:
            print(
                f"......Word '{word.content}' has a confidence of {word.confidence}"
            )
    
     # Iterate through each selection mark in the page
    for selection_mark in page.selection_marks:

        # Print information about each selection mark
        print(
            f"Selection mark is '{selection_mark.state}' within bounding polygon "
            f"'{selection_mark.polygon}' and has a confidence of {selection_mark.confidence}"
        )

# Iterate through each table in the document
for table_idx, table in enumerate(result.tables):
    # Print information about each table
    print(
        f"Table # {table_idx} has {table.row_count} rows and "
        f"{table.column_count} columns"
    )
    # Iterate through each region bounding the table
    for region in table.bounding_regions:
        # Print information about the location of the table on the page
        print(
            f"Table # {table_idx} location on page: {region.page_number} is {region.polygon}"
        )
    # Iterate through each cell in the table
    for cell in table.cells:
        # Print information about each cell
        print(
            f"...Cell[{cell.row_index}][{cell.column_index}] has text '{cell.content}'"
        )
        # Iterate through each region bounding the cell's content
        for region in cell.bounding_regions:
            # Print information about the region bounding the cell's content
            print(
                f"...content on page {region.page_number} is within bounding polygon '{region.polygon}'"
            )
# Out:
# <azure.core.polling._poller.LROPoller object at 0x7fa94297f670>
# Document contains handwritten content
# ----Analyzing layout from page #1----
# Page has width: 8.2639 and height: 11.6806, measured with unit: inch
# ...Line # 0 has word count 1 and text '☒' within bounding polygon '[Point(x=0.2442, y=1.5856), Point(x=0.3408, y=1.5856), Point(x=0.3408, y=1.6837), Point(x=0.2442, y=1.6837)]'
# ......Word '☒' has a confidence of 1.0
# ...Line # 1 has word count 14 and text 'QUARTERLY REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF' within bounding polygon '[Point(x=0.5678, y=1.5615), Point(x=6.7024, y=1.5615), Point(x=6.7024, y=1.7237), Point(x=0.5678, y=1.7237)]'
# ......Word 'QUARTERLY' has a confidence of 0.994
# ......Word 'REPORT' has a confidence of 0.995
# ......Word 'PURSUANT' has a confidence of 0.993
# ......Word 'TO' has a confidence of 0.996
# ......Word 'SECTION' has a confidence of 0.993
# ......Word '13' has a confidence of 0.995
# ......Word 'OR' has a confidence of 0.995
# ......Word '15(d)' has a confidence of 0.951
# ......Word 'OF' has a confidence of 0.996
# ......Word 'THE' has a confidence of 0.996
# ......Word 'SECURITIES' has a confidence of 0.983
# ......Word 'EXCHANGE' has a confidence of 0.993
# ......Word 'ACT' has a confidence of 0.981
# ......Word 'OF' has a confidence of 0.996
# ...Line # 2 has word count 9 and text '1934 For the Quarterly Period Ended March 31, 2020' within bounding polygon '[Point(x=0.5932, y=1.7592), Point(x=3.6959, y=1.7592), Point(x=3.6959, y=1.9163), Point(x=0.5932, y=1.9163)]'
# ......Word '1934' has a confidence of 0.991
# ......Word 'For' has a confidence of 0.996
# ......Word 'the' has a confidence of 0.996
# ......Word 'Quarterly' has a confidence of 0.993
# ......Word 'Period' has a confidence of 0.995
# ......Word 'Ended' has a confidence of 0.993
# ......Word 'March' has a confidence of 0.961
# ......Word '31,' has a confidence of 0.995
# ......Word '2020' has a confidence of 0.992
# ...Line # 3 has word count 2 and text 'UNITED STATES' within bounding polygon '[Point(x=3.2447, y=0.3752), Point(x=4.9989, y=0.3752), Point(x=4.9989, y=0.583), Point(x=3.2447, y=0.5881)]'
# ......Word 'UNITED' has a confidence of 0.995
# ......Word 'STATES' has a confidence of 0.994
# ...Line # 4 has word count 4 and text 'SECURITIES AND EXCHANGE COMMISSION' within bounding polygon '[Point(x=1.7542, y=0.6591), Point(x=6.4742, y=0.6591), Point(x=6.4742, y=0.8821), Point(x=1.7542, y=0.8821)]'
# ......Word 'SECURITIES' has a confidence of 0.99
# ......Word 'AND' has a confidence of 0.997
# ......Word 'EXCHANGE' has a confidence of 0.995
# ......Word 'COMMISSION' has a confidence of 0.983
# ...Line # 5 has word count 3 and text 'Washington, D.C. 20549' within bounding polygon '[Point(x=3.2549, y=0.8923), Point(x=4.9989, y=0.8872), Point(x=4.9989, y=1.0748), Point(x=3.2549, y=1.0798)]'
# ......Word 'Washington,' has a confidence of 0.992
# ......Word 'D.C.' has a confidence of 0.993
# ......Word '20549' has a confidence of 0.995
# ...Line # 6 has word count 2 and text 'FORM 10-Q' within bounding polygon '[Point(x=3.5134, y=1.1812), Point(x=4.7403, y=1.1863), Point(x=4.7403, y=1.4043), Point(x=3.5134, y=1.3992)]'
# ......Word 'FORM' has a confidence of 0.993
# ......Word '10-Q' has a confidence of 0.993
# ...Line # 7 has word count 1 and text 'OR' within bounding polygon '[Point(x=3.9951, y=1.9822), Point(x=4.2536, y=1.9873), Point(x=4.2536, y=2.1394), Point(x=3.9951, y=2.1343)]'
# ......Word 'OR' has a confidence of 0.993
# ...Line # 8 has word count 1 and text '☐' within bounding polygon '[Point(x=0.2442, y=2.2791), Point(x=0.3414, y=2.2791), Point(x=0.3414, y=2.3772), Point(x=0.2442, y=2.3772)]'
# ......Word '☐' has a confidence of 1.0
# ...Line # 9 has word count 15 and text 'TRANSITION REPORT PURSUANT TO SECTION 13 OR 15(d) OF THE SECURITIES EXCHANGE ACT OF 1934' within bounding polygon '[Point(x=0.5729, y=2.256), Point(x=7.0218, y=2.256), Point(x=7.0218, y=2.4182), Point(x=0.5729, y=2.4182)]'
# ......Word 'TRANSITION' has a confidence of 0.992
# ......Word 'REPORT' has a confidence of 0.994
# ......Word 'PURSUANT' has a confidence of 0.992
# ......Word 'TO' has a confidence of 0.995
# ......Word 'SECTION' has a confidence of 0.993
# ......Word '13' has a confidence of 0.995
# ......Word 'OR' has a confidence of 0.995
# ......Word '15(d)' has a confidence of 0.99
# ......Word 'OF' has a confidence of 0.996
# ......Word 'THE' has a confidence of 0.996
# ......Word 'SECURITIES' has a confidence of 0.993
# ......Word 'EXCHANGE' has a confidence of 0.993
# ......Word 'ACT' has a confidence of 0.996
# ......Word 'OF' has a confidence of 0.995
# ......Word '1934' has a confidence of 0.986
# ...Line # 10 has word count 5 and text 'For the Transition Period From' within bounding polygon '[Point(x=0.5475, y=2.4841), Point(x=2.4285, y=2.4841), Point(x=2.4285, y=2.6717), Point(x=0.5475, y=2.6667)]'
# ......Word 'For' has a confidence of 0.996
# ......Word 'the' has a confidence of 0.996
# ......Word 'Transition' has a confidence of 0.993
# ......Word 'Period' has a confidence of 0.994
# ......Word 'From' has a confidence of 0.993
# ...Line # 11 has word count 1 and text 'to' within bounding polygon '[Point(x=3.0318, y=2.5146), Point(x=3.1535, y=2.5146), Point(x=3.1585, y=2.6261), Point(x=3.0369, y=2.6261)]'
# ......Word 'to' has a confidence of 0.996
# ...Line # 12 has word count 4 and text 'Commission File Number 001-37845' within bounding polygon '[Point(x=3.0318, y=2.692), Point(x=5.2017, y=2.692), Point(x=5.2017, y=2.839), Point(x=3.0318, y=2.839)]'
# ......Word 'Commission' has a confidence of 0.993
# ......Word 'File' has a confidence of 0.983
# ......Word 'Number' has a confidence of 0.994
# ......Word '001-37845' has a confidence of 0.994
# ...Line # 13 has word count 2 and text 'MICROSOFT CORPORATION' within bounding polygon '[Point(x=2.0685, y=3.0165), Point(x=6.17, y=3.0165), Point(x=6.17, y=3.2598), Point(x=2.0685, y=3.2598)]'
# ......Word 'MICROSOFT' has a confidence of 0.995
# ......Word 'CORPORATION' has a confidence of 0.993
# ...Line # 14 has word count 1 and text 'WASHINGTON' within bounding polygon '[Point(x=1.7795, y=3.3916), Point(x=2.5299, y=3.3916), Point(x=2.5299, y=3.5133), Point(x=1.7795, y=3.5133)]'
# ......Word 'WASHINGTON' has a confidence of 0.993
# ...Line # 15 has word count 3 and text '(STATE OF INCORPORATION)' within bounding polygon '[Point(x=1.4956, y=3.5285), Point(x=2.8239, y=3.5285), Point(x=2.8188, y=3.6552), Point(x=1.4956, y=3.6502)]'
# ......Word '(STATE' has a confidence of 0.994
# ......Word 'OF' has a confidence of 0.996
# ......Word 'INCORPORATION)' has a confidence of 0.989
# ...Line # 16 has word count 6 and text 'ONE MICROSOFT WAY, REDMOND, WASHINGTON 98052-6399' within bounding polygon '[Point(x=2.5451, y=3.6654), Point(x=5.6884, y=3.6603), Point(x=5.6884, y=3.7921), Point(x=2.5451, y=3.7972)]'
# ......Word 'ONE' has a confidence of 0.993
# ......Word 'MICROSOFT' has a confidence of 0.995
# ......Word 'WAY,' has a confidence of 0.992
# ......Word 'REDMOND,' has a confidence of 0.994
# ......Word 'WASHINGTON' has a confidence of 0.994
# ......Word '98052-6399' has a confidence of 0.993
# ...Line # 17 has word count 2 and text '(425) 882-8080' within bounding polygon '[Point(x=3.7517, y=3.7921), Point(x=4.4818, y=3.7921), Point(x=4.4818, y=3.9087), Point(x=3.7517, y=3.9138)]'
# ......Word '(425)' has a confidence of 0.995
# ......Word '882-8080' has a confidence of 0.994
# ...Line # 18 has word count 1 and text 'www.microsoft.com/investor' within bounding polygon '[Point(x=3.3816, y=3.9138), Point(x=4.8316, y=3.9138), Point(x=4.8316, y=4.0304), Point(x=3.3816, y=4.0304)]'
# ......Word 'www.microsoft.com/investor' has a confidence of 0.962
# ...Line # 19 has word count 1 and text '91-1144442' within bounding polygon '[Point(x=5.8405, y=3.3967), Point(x=6.4185, y=3.3967), Point(x=6.4185, y=3.5133), Point(x=5.8405, y=3.5133)]'
# ......Word '91-1144442' has a confidence of 0.993
# ...Line # 20 has word count 2 and text '(I.R.S. ID)' within bounding polygon '[Point(x=5.8912, y=3.5386), Point(x=6.3171, y=3.5386), Point(x=6.3171, y=3.6502), Point(x=5.8912, y=3.6502)]'
# ......Word '(I.R.S.' has a confidence of 0.931
# ......Word 'ID)' has a confidence of 0.995
# ...Line # 21 has word count 9 and text 'Securities registered pursuant to Section 12(b) of the Act:' within bounding polygon '[Point(x=0.2028, y=4.071), Point(x=2.8746, y=4.071), Point(x=2.8746, y=4.2028), Point(x=0.2028, y=4.2078)]'
# ......Word 'Securities' has a confidence of 0.976
# ......Word 'registered' has a confidence of 0.914
# ......Word 'pursuant' has a confidence of 0.98
# ......Word 'to' has a confidence of 0.995
# ......Word 'Section' has a confidence of 0.992
# ......Word '12(b)' has a confidence of 0.99
# ......Word 'of' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.996
# ......Word 'Act:' has a confidence of 0.973
# ...Line # 22 has word count 4 and text 'Title of each class' within bounding polygon '[Point(x=0.2079, y=4.2332), Point(x=1.0697, y=4.2332), Point(x=1.0647, y=4.3549), Point(x=0.2079, y=4.3498)]'
# ......Word 'Title' has a confidence of 0.995
# ......Word 'of' has a confidence of 0.995
# ......Word 'each' has a confidence of 0.993
# ......Word 'class' has a confidence of 0.995
# ...Line # 23 has word count 2 and text 'Trading Symbol' within bounding polygon '[Point(x=4.2688, y=4.2383), Point(x=5.0141, y=4.2383), Point(x=5.0141, y=4.365), Point(x=4.2688, y=4.3599)]'
# ......Word 'Trading' has a confidence of 0.995
# ......Word 'Symbol' has a confidence of 0.995
# ...Line # 24 has word count 6 and text 'Name of exchange on which registered' within bounding polygon '[Point(x=5.7036, y=4.2332), Point(x=7.5389, y=4.2332), Point(x=7.5389, y=4.365), Point(x=5.7036, y=4.3599)]'
# ......Word 'Name' has a confidence of 0.982
# ......Word 'of' has a confidence of 0.996
# ......Word 'exchange' has a confidence of 0.994
# ......Word 'on' has a confidence of 0.997
# ......Word 'which' has a confidence of 0.995
# ......Word 'registered' has a confidence of 0.993
# ...Line # 25 has word count 7 and text 'Common stock, $0.00000625 par value per share' within bounding polygon '[Point(x=0.2028, y=4.3599), Point(x=2.6262, y=4.365), Point(x=2.6262, y=4.4968), Point(x=0.2028, y=4.4867)]'
# ......Word 'Common' has a confidence of 0.995
# ......Word 'stock,' has a confidence of 0.993
# ......Word '$0.00000625' has a confidence of 0.991
# ......Word 'par' has a confidence of 0.995
# ......Word 'value' has a confidence of 0.995
# ......Word 'per' has a confidence of 0.996
# ......Word 'share' has a confidence of 0.995
# ...Line # 26 has word count 1 and text 'MSFT' within bounding polygon '[Point(x=4.4919, y=4.3701), Point(x=4.786, y=4.3701), Point(x=4.791, y=4.4765), Point(x=4.497, y=4.4765)]'
# ......Word 'MSFT' has a confidence of 0.992
# ...Line # 27 has word count 1 and text 'NASDAQ' within bounding polygon '[Point(x=6.383, y=4.365), Point(x=6.8545, y=4.365), Point(x=6.8545, y=4.4816), Point(x=6.383, y=4.4816)]'
# ......Word 'NASDAQ' has a confidence of 0.995
# ...Line # 28 has word count 4 and text '2.125% Notes due 2021' within bounding polygon '[Point(x=0.2028, y=4.4816), Point(x=1.3739, y=4.4816), Point(x=1.3739, y=4.6033), Point(x=0.2028, y=4.6033)]'
# ......Word '2.125%' has a confidence of 0.961
# ......Word 'Notes' has a confidence of 0.995
# ......Word 'due' has a confidence of 0.995
# ......Word '2021' has a confidence of 0.992
# ...Line # 29 has word count 1 and text 'MSFT' within bounding polygon '[Point(x=4.4818, y=4.4867), Point(x=4.791, y=4.4867), Point(x=4.791, y=4.5931), Point(x=4.4868, y=4.5931)]'
# ......Word 'MSFT' has a confidence of 0.991
# ...Line # 30 has word count 1 and text 'NASDAQ' within bounding polygon '[Point(x=6.383, y=4.4867), Point(x=6.8595, y=4.4867), Point(x=6.8595, y=4.5982), Point(x=6.383, y=4.5931)]'
# ......Word 'NASDAQ' has a confidence of 0.995
# ...Line # 31 has word count 4 and text '3.125% Notes due 2028' within bounding polygon '[Point(x=0.2028, y=4.5881), Point(x=1.3739, y=4.5881), Point(x=1.3739, y=4.7148), Point(x=0.2028, y=4.7148)]'
# ......Word '3.125%' has a confidence of 0.981
# ......Word 'Notes' has a confidence of 0.994
# ......Word 'due' has a confidence of 0.995
# ......Word '2028' has a confidence of 0.992
# ...Line # 32 has word count 1 and text 'MSFT' within bounding polygon '[Point(x=4.4868, y=4.5982), Point(x=4.791, y=4.5982), Point(x=4.791, y=4.7047), Point(x=4.497, y=4.7047)]'
# ......Word 'MSFT' has a confidence of 0.991
# ...Line # 33 has word count 1 and text 'NASDAQ' within bounding polygon '[Point(x=6.383, y=4.5931), Point(x=6.8646, y=4.5982), Point(x=6.8595, y=4.7097), Point(x=6.383, y=4.7047)]'
# ......Word 'NASDAQ' has a confidence of 0.992
# ...Line # 34 has word count 4 and text '2.625% Notes due 2033' within bounding polygon '[Point(x=0.2028, y=4.7249), Point(x=1.379, y=4.7249), Point(x=1.379, y=4.8517), Point(x=0.2028, y=4.8568)]'
# ......Word '2.625%' has a confidence of 0.995
# ......Word 'Notes' has a confidence of 0.993
# ......Word 'due' has a confidence of 0.99
# ......Word '2033' has a confidence of 0.991
# ...Line # 35 has word count 1 and text 'MSFT' within bounding polygon '[Point(x=4.4818, y=4.7351), Point(x=4.7961, y=4.7351), Point(x=4.7961, y=4.8466), Point(x=4.4868, y=4.8416)]'
# ......Word 'MSFT' has a confidence of 0.991
# ...Line # 36 has word count 1 and text 'NASDAQ' within bounding polygon '[Point(x=6.383, y=4.73), Point(x=6.8646, y=4.73), Point(x=6.8646, y=4.8466), Point(x=6.383, y=4.8466)]'
# ......Word 'NASDAQ' has a confidence of 0.995
# ...Line # 37 has word count 9 and text 'Securities registered pursuant to Section 12(g) of the Act:' within bounding polygon '[Point(x=0.1977, y=4.8922), Point(x=2.8645, y=4.8872), Point(x=2.8645, y=5.0241), Point(x=0.1977, y=5.0241)]'
# ......Word 'Securities' has a confidence of 0.972
# ......Word 'registered' has a confidence of 0.964
# ......Word 'pursuant' has a confidence of 0.99
# ......Word 'to' has a confidence of 0.995
# ......Word 'Section' has a confidence of 0.987
# ......Word '12(g)' has a confidence of 0.966
# ......Word 'of' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.995
# ......Word 'Act:' has a confidence of 0.979
# ...Line # 38 has word count 1 and text 'NONE' within bounding polygon '[Point(x=0.2028, y=5.0595), Point(x=0.5222, y=5.0545), Point(x=0.5222, y=5.166), Point(x=0.2028, y=5.166)]'
# ......Word 'NONE' has a confidence of 0.992
# ...Line # 39 has word count 30 and text 'Indicate by check mark whether the registrant (1) has filed all reports required to be filed by Section 13 or 15(d) of the Securities Exchange Act of 1934 during the' within bounding polygon '[Point(x=0.2079, y=5.2066), Point(x=8.0307, y=5.2066), Point(x=8.0307, y=5.3384), Point(x=0.2079, y=5.3384)]'
# ......Word 'Indicate' has a confidence of 0.98
# ......Word 'by' has a confidence of 0.995
# ......Word 'check' has a confidence of 0.994
# ......Word 'mark' has a confidence of 0.992
# ......Word 'whether' has a confidence of 0.993
# ......Word 'the' has a confidence of 0.995
# ......Word 'registrant' has a confidence of 0.972
# ......Word '(1)' has a confidence of 0.989
# ......Word 'has' has a confidence of 0.995
# ......Word 'filed' has a confidence of 0.993
# ......Word 'all' has a confidence of 0.995
# ......Word 'reports' has a confidence of 0.988
# ......Word 'required' has a confidence of 0.982
# ......Word 'to' has a confidence of 0.995
# ......Word 'be' has a confidence of 0.9
# ......Word 'filed' has a confidence of 0.993
# ......Word 'by' has a confidence of 0.995
# ......Word 'Section' has a confidence of 0.993
# ......Word '13' has a confidence of 0.995
# ......Word 'or' has a confidence of 0.995
# ......Word '15(d)' has a confidence of 0.99
# ......Word 'of' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.995
# ......Word 'Securities' has a confidence of 0.982
# ......Word 'Exchange' has a confidence of 0.995
# ......Word 'Act' has a confidence of 0.995
# ......Word 'of' has a confidence of 0.995
# ......Word '1934' has a confidence of 0.991
# ......Word 'during' has a confidence of 0.994
# ......Word 'the' has a confidence of 0.995
# ...Line # 40 has word count 30 and text 'preceding 12 months (or for such shorter period that the registrant was required to file such reports), and (2) has been subject to such filing requirements for the past 90' within bounding polygon '[Point(x=0.2028, y=5.3384), Point(x=8.0256, y=5.3384), Point(x=8.0256, y=5.4702), Point(x=0.2028, y=5.4702)]'
# ......Word 'preceding' has a confidence of 0.992
# ......Word '12' has a confidence of 0.995
# ......Word 'months' has a confidence of 0.993
# ......Word '(or' has a confidence of 0.995
# ......Word 'for' has a confidence of 0.995
# ......Word 'such' has a confidence of 0.992
# ......Word 'shorter' has a confidence of 0.993
# ......Word 'period' has a confidence of 0.993
# ......Word 'that' has a confidence of 0.992
# ......Word 'the' has a confidence of 0.993
# ......Word 'registrant' has a confidence of 0.984
# ......Word 'was' has a confidence of 0.995
# ......Word 'required' has a confidence of 0.98
# ......Word 'to' has a confidence of 0.995
# ......Word 'file' has a confidence of 0.99
# ......Word 'such' has a confidence of 0.992
# ......Word 'reports),' has a confidence of 0.961
# ......Word 'and' has a confidence of 0.995
# ......Word '(2)' has a confidence of 0.979
# ......Word 'has' has a confidence of 0.995
# ......Word 'been' has a confidence of 0.992
# ......Word 'subject' has a confidence of 0.993
# ......Word 'to' has a confidence of 0.995
# ......Word 'such' has a confidence of 0.992
# ......Word 'filing' has a confidence of 0.981
# ......Word 'requirements' has a confidence of 0.983
# ......Word 'for' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.996
# ......Word 'past' has a confidence of 0.993
# ......Word '90' has a confidence of 0.994
# ...Line # 41 has word count 2 and text 'days. Yes' within bounding polygon '[Point(x=0.2079, y=5.4753), Point(x=0.7098, y=5.4753), Point(x=0.7149, y=5.5767), Point(x=0.2079, y=5.5817)]'
# ......Word 'days.' has a confidence of 0.994
# ......Word 'Yes' has a confidence of 0.995
# ...Line # 42 has word count 1 and text 'No' within bounding polygon '[Point(x=0.8213, y=5.4803), Point(x=0.9886, y=5.4803), Point(x=0.9886, y=5.5716), Point(x=0.8264, y=5.5665)]'
# ......Word 'No' has a confidence of 0.995
# ...Line # 43 has word count 25 and text 'Indicate by check mark whether the registrant has submitted electronically every Interactive Data File required to be submitted pursuant to Rule 405 of Regulation S-T' within bounding polygon '[Point(x=0.2079, y=5.6223), Point(x=8.0307, y=5.6223), Point(x=8.0307, y=5.749), Point(x=0.2079, y=5.749)]'
# ......Word 'Indicate' has a confidence of 0.985
# ......Word 'by' has a confidence of 0.995
# ......Word 'check' has a confidence of 0.995
# ......Word 'mark' has a confidence of 0.992
# ......Word 'whether' has a confidence of 0.994
# ......Word 'the' has a confidence of 0.996
# ......Word 'registrant' has a confidence of 0.987
# ......Word 'has' has a confidence of 0.995
# ......Word 'submitted' has a confidence of 0.978
# ......Word 'electronically' has a confidence of 0.974
# ......Word 'every' has a confidence of 0.944
# ......Word 'Interactive' has a confidence of 0.961
# ......Word 'Data' has a confidence of 0.991
# ......Word 'File' has a confidence of 0.992
# ......Word 'required' has a confidence of 0.988
# ......Word 'to' has a confidence of 0.995
# ......Word 'be' has a confidence of 0.995
# ......Word 'submitted' has a confidence of 0.98
# ......Word 'pursuant' has a confidence of 0.985
# ......Word 'to' has a confidence of 0.995
# ......Word 'Rule' has a confidence of 0.991
# ......Word '405' has a confidence of 0.995
# ......Word 'of' has a confidence of 0.995
# ......Word 'Regulation' has a confidence of 0.983
# ......Word 'S-T' has a confidence of 0.995
# ...Line # 44 has word count 24 and text '(§232.405 of this chapter) during the preceding 12 months (or for such shorter period that the registrant was required to submit such files). Yes' within bounding polygon '[Point(x=0.2129, y=5.7541), Point(x=6.7784, y=5.7541), Point(x=6.7784, y=5.8808), Point(x=0.2129, y=5.8808)]'
# ......Word '(§232.405' has a confidence of 0.982
# ......Word 'of' has a confidence of 0.995
# ......Word 'this' has a confidence of 0.992
# ......Word 'chapter)' has a confidence of 0.993
# ......Word 'during' has a confidence of 0.994
# ......Word 'the' has a confidence of 0.995
# ......Word 'preceding' has a confidence of 0.982
# ......Word '12' has a confidence of 0.994
# ......Word 'months' has a confidence of 0.993
# ......Word '(or' has a confidence of 0.995
# ......Word 'for' has a confidence of 0.996
# ......Word 'such' has a confidence of 0.992
# ......Word 'shorter' has a confidence of 0.993
# ......Word 'period' has a confidence of 0.993
# ......Word 'that' has a confidence of 0.992
# ......Word 'the' has a confidence of 0.997
# ......Word 'registrant' has a confidence of 0.992
# ......Word 'was' has a confidence of 0.994
# ......Word 'required' has a confidence of 0.993
# ......Word 'to' has a confidence of 0.995
# ......Word 'submit' has a confidence of 0.99
# ......Word 'such' has a confidence of 0.991
# ......Word 'files).' has a confidence of 0.933
# ......Word 'Yes' has a confidence of 0.995
# ...Line # 45 has word count 2 and text 'X No' within bounding polygon '[Point(x=6.819, y=5.7592), Point(x=7.0877, y=5.7642), Point(x=7.0877, y=5.8707), Point(x=6.819, y=5.8656)]'
# ......Word 'X' has a confidence of 0.552
# ......Word 'No' has a confidence of 0.995
# ...Line # 46 has word count 25 and text 'Indicate by check mark whether the registrant is a large accelerated filer, an accelerated filer, a non-accelerated filer, a smaller reporting company, or an emerging' within bounding polygon '[Point(x=0.2028, y=5.896), Point(x=8.0256, y=5.9011), Point(x=8.0256, y=6.0279), Point(x=0.2028, y=6.0228)]'
# ......Word 'Indicate' has a confidence of 0.974
# ......Word 'by' has a confidence of 0.995
# ......Word 'check' has a confidence of 0.995
# ......Word 'mark' has a confidence of 0.993
# ......Word 'whether' has a confidence of 0.994
# ......Word 'the' has a confidence of 0.996
# ......Word 'registrant' has a confidence of 0.992
# ......Word 'is' has a confidence of 0.995
# ......Word 'a' has a confidence of 0.995
# ......Word 'large' has a confidence of 0.993
# ......Word 'accelerated' has a confidence of 0.99
# ......Word 'filer,' has a confidence of 0.993
# ......Word 'an' has a confidence of 0.996
# ......Word 'accelerated' has a confidence of 0.991
# ......Word 'filer,' has a confidence of 0.992
# ......Word 'a' has a confidence of 0.995
# ......Word 'non-accelerated' has a confidence of 0.983
# ......Word 'filer,' has a confidence of 0.991
# ......Word 'a' has a confidence of 0.995
# ......Word 'smaller' has a confidence of 0.993
# ......Word 'reporting' has a confidence of 0.983
# ......Word 'company,' has a confidence of 0.961
# ......Word 'or' has a confidence of 0.996
# ......Word 'an' has a confidence of 0.997
# ......Word 'emerging' has a confidence of 0.993
# ...Line # 47 has word count 23 and text 'growth company. See the definitions of "large accelerated filer," "accelerated filer," "smaller reporting company," and "emerging growth company" in Rule 12b-2 of the' within bounding polygon '[Point(x=0.2028, y=6.0228), Point(x=8.0307, y=6.0228), Point(x=8.0307, y=6.1495), Point(x=0.2028, y=6.1495)]'
# ......Word 'growth' has a confidence of 0.995
# ......Word 'company.' has a confidence of 0.993
# ......Word 'See' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.995
# ......Word 'definitions' has a confidence of 0.964
# ......Word 'of' has a confidence of 0.995
# ......Word '"large' has a confidence of 0.947
# ......Word 'accelerated' has a confidence of 0.982
# ......Word 'filer,"' has a confidence of 0.944
# ......Word '"accelerated' has a confidence of 0.948
# ......Word 'filer,"' has a confidence of 0.916
# ......Word '"smaller' has a confidence of 0.972
# ......Word 'reporting' has a confidence of 0.989
# ......Word 'company,"' has a confidence of 0.929
# ......Word 'and' has a confidence of 0.995
# ......Word '"emerging' has a confidence of 0.936
# ......Word 'growth' has a confidence of 0.994
# ......Word 'company"' has a confidence of 0.948
# ......Word 'in' has a confidence of 0.995
# ......Word 'Rule' has a confidence of 0.991
# ......Word '12b-2' has a confidence of 0.989
# ......Word 'of' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.996
# ...Line # 48 has word count 2 and text 'Exchange Act.' within bounding polygon '[Point(x=0.2028, y=6.1394), Point(x=0.8872, y=6.1445), Point(x=0.8872, y=6.2611), Point(x=0.2028, y=6.256)]'
# ......Word 'Exchange' has a confidence of 0.995
# ......Word 'Act.' has a confidence of 0.989
# ...Line # 49 has word count 1 and text 'X' within bounding polygon '[Point(x=1.3638, y=6.332), Point(x=1.3638, y=6.403), Point(x=1.2776, y=6.4081), Point(x=1.2827, y=6.332)]'
# ......Word 'X' has a confidence of 0.816
# ...Line # 50 has word count 3 and text 'Large accelerated filer' within bounding polygon '[Point(x=0.2079, y=6.3118), Point(x=1.2776, y=6.3118), Point(x=1.2776, y=6.4233), Point(x=0.2129, y=6.4334)]'
# ......Word 'Large' has a confidence of 0.995
# ......Word 'accelerated' has a confidence of 0.993
# ......Word 'filer' has a confidence of 0.995
# ...Line # 51 has word count 2 and text 'Accelerated filer' within bounding polygon '[Point(x=6.0027, y=6.3067), Point(x=6.7733, y=6.3067), Point(x=6.7733, y=6.4284), Point(x=6.0027, y=6.4284)]'
# ......Word 'Accelerated' has a confidence of 0.993
# ......Word 'filer' has a confidence of 0.995
# ...Line # 52 has word count 2 and text 'Non-accelerated filer' within bounding polygon '[Point(x=0.2028, y=6.4791), Point(x=1.1965, y=6.474), Point(x=1.1965, y=6.5906), Point(x=0.2028, y=6.5957)]'
# ......Word 'Non-accelerated' has a confidence of 0.983
# ......Word 'filer' has a confidence of 0.995
# ...Line # 53 has word count 3 and text 'Smaller reporting company' within bounding polygon '[Point(x=6.0129, y=6.4689), Point(x=7.3006, y=6.4841), Point(x=7.3006, y=6.6109), Point(x=6.0129, y=6.5957)]'
# ......Word 'Smaller' has a confidence of 0.995
# ......Word 'reporting' has a confidence of 0.994
# ......Word 'company' has a confidence of 0.995
# ...Line # 54 has word count 3 and text 'Emerging growth company' within bounding polygon '[Point(x=6.0129, y=6.5957), Point(x=7.2803, y=6.6007), Point(x=7.2803, y=6.7275), Point(x=6.0129, y=6.7275)]'
# ......Word 'Emerging' has a confidence of 0.994
# ......Word 'growth' has a confidence of 0.995
# ......Word 'company' has a confidence of 0.995
# ...Line # 55 has word count 28 and text 'If an emerging growth company, indicate by check mark if the registrant has elected not to use the extended transition period for complying with any new or revised' within bounding polygon '[Point(x=0.2028, y=6.8035), Point(x=7.7316, y=6.8086), Point(x=7.7316, y=6.9353), Point(x=0.2028, y=6.9353)]'
# ......Word 'If' has a confidence of 0.973
# ......Word 'an' has a confidence of 0.995
# ......Word 'emerging' has a confidence of 0.993
# ......Word 'growth' has a confidence of 0.995
# ......Word 'company,' has a confidence of 0.992
# ......Word 'indicate' has a confidence of 0.992
# ......Word 'by' has a confidence of 0.96
# ......Word 'check' has a confidence of 0.993
# ......Word 'mark' has a confidence of 0.989
# ......Word 'if' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.996
# ......Word 'registrant' has a confidence of 0.991
# ......Word 'has' has a confidence of 0.995
# ......Word 'elected' has a confidence of 0.993
# ......Word 'not' has a confidence of 0.995
# ......Word 'to' has a confidence of 0.996
# ......Word 'use' has a confidence of 0.994
# ......Word 'the' has a confidence of 0.996
# ......Word 'extended' has a confidence of 0.993
# ......Word 'transition' has a confidence of 0.98
# ......Word 'period' has a confidence of 0.991
# ......Word 'for' has a confidence of 0.949
# ......Word 'complying' has a confidence of 0.993
# ......Word 'with' has a confidence of 0.993
# ......Word 'any' has a confidence of 0.996
# ......Word 'new' has a confidence of 0.996
# ......Word 'or' has a confidence of 0.996
# ......Word 'revised' has a confidence of 0.994
# ...Line # 56 has word count 12 and text 'financial accounting standards provided pursuant to Section 13(a) of the Exchange Act.' within bounding polygon '[Point(x=0.1977, y=6.9353), Point(x=4.2486, y=6.9303), Point(x=4.2486, y=7.057), Point(x=0.1977, y=7.057)]'
# ......Word 'financial' has a confidence of 0.983
# ......Word 'accounting' has a confidence of 0.993
# ......Word 'standards' has a confidence of 0.991
# ......Word 'provided' has a confidence of 0.992
# ......Word 'pursuant' has a confidence of 0.977
# ......Word 'to' has a confidence of 0.995
# ......Word 'Section' has a confidence of 0.993
# ......Word '13(a)' has a confidence of 0.989
# ......Word 'of' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.994
# ......Word 'Exchange' has a confidence of 0.994
# ......Word 'Act.' has a confidence of 0.981
# ...Line # 57 has word count 21 and text 'Indicate by check mark whether the registrant is a shell company (as defined in Rule 12b-2 of the Exchange Act). Yes' within bounding polygon '[Point(x=0.2079, y=7.1229), Point(x=5.6732, y=7.1229), Point(x=5.6732, y=7.2497), Point(x=0.2079, y=7.2497)]'
# ......Word 'Indicate' has a confidence of 0.969
# ......Word 'by' has a confidence of 0.995
# ......Word 'check' has a confidence of 0.994
# ......Word 'mark' has a confidence of 0.99
# ......Word 'whether' has a confidence of 0.994
# ......Word 'the' has a confidence of 0.995
# ......Word 'registrant' has a confidence of 0.99
# ......Word 'is' has a confidence of 0.995
# ......Word 'a' has a confidence of 0.995
# ......Word 'shell' has a confidence of 0.994
# ......Word 'company' has a confidence of 0.995
# ......Word '(as' has a confidence of 0.961
# ......Word 'defined' has a confidence of 0.975
# ......Word 'in' has a confidence of 0.995
# ......Word 'Rule' has a confidence of 0.991
# ......Word '12b-2' has a confidence of 0.991
# ......Word 'of' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.995
# ......Word 'Exchange' has a confidence of 0.994
# ......Word 'Act).' has a confidence of 0.977
# ......Word 'Yes' has a confidence of 0.961
# ...Line # 58 has word count 1 and text 'No' within bounding polygon '[Point(x=6.0788, y=7.1381), Point(x=6.2562, y=7.1381), Point(x=6.2562, y=7.2344), Point(x=6.0788, y=7.2294)]'
# ......Word 'No' has a confidence of 0.995
# ...Line # 59 has word count 21 and text 'Indicate the number of shares outstanding of each of the issuer's classes of common stock, as of the latest practicable date.' within bounding polygon '[Point(x=0.2028, y=7.2851), Point(x=5.9267, y=7.2851), Point(x=5.9267, y=7.4017), Point(x=0.2028, y=7.4068)]'
# ......Word 'Indicate' has a confidence of 0.982
# ......Word 'the' has a confidence of 0.996
# ......Word 'number' has a confidence of 0.985
# ......Word 'of' has a confidence of 0.995
# ......Word 'shares' has a confidence of 0.995
# ......Word 'outstanding' has a confidence of 0.991
# ......Word 'of' has a confidence of 0.995
# ......Word 'each' has a confidence of 0.993
# ......Word 'of' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.989
# ......Word 'issuer's' has a confidence of 0.993
# ......Word 'classes' has a confidence of 0.993
# ......Word 'of' has a confidence of 0.995
# ......Word 'common' has a confidence of 0.995
# ......Word 'stock,' has a confidence of 0.992
# ......Word 'as' has a confidence of 0.995
# ......Word 'of' has a confidence of 0.996
# ......Word 'the' has a confidence of 0.996
# ......Word 'latest' has a confidence of 0.993
# ......Word 'practicable' has a confidence of 0.99
# ......Word 'date.' has a confidence of 0.993
# ...Line # 60 has word count 1 and text 'Class' within bounding polygon '[Point(x=0.2079, y=7.4626), Point(x=0.4614, y=7.4626), Point(x=0.4614, y=7.5589), Point(x=0.2079, y=7.5538)]'
# ......Word 'Class' has a confidence of 0.995
# ...Line # 61 has word count 6 and text 'Outstanding as of April 24, 2020' within bounding polygon '[Point(x=6.4996, y=7.4474), Point(x=7.8989, y=7.4474), Point(x=7.8989, y=7.564), Point(x=6.4996, y=7.569)]'
# ......Word 'Outstanding' has a confidence of 0.988
# ......Word 'as' has a confidence of 0.995
# ......Word 'of' has a confidence of 0.996
# ......Word 'April' has a confidence of 0.995
# ......Word '24,' has a confidence of 0.994
# ......Word '2020' has a confidence of 0.992
# ...Line # 62 has word count 7 and text 'Common Stock, $0.00000625 par value per share' within bounding polygon '[Point(x=0.1977, y=7.6451), Point(x=2.5299, y=7.6451), Point(x=2.5299, y=7.7668), Point(x=0.1977, y=7.7668)]'
# ......Word 'Common' has a confidence of 0.995
# ......Word 'Stock,' has a confidence of 0.993
# ......Word '$0.00000625' has a confidence of 0.991
# ......Word 'par' has a confidence of 0.996
# ......Word 'value' has a confidence of 0.995
# ......Word 'per' has a confidence of 0.995
# ......Word 'share' has a confidence of 0.995
# ...Line # 63 has word count 2 and text '7,583,440,247 shares' within bounding polygon '[Point(x=6.9001, y=7.6502), Point(x=7.9546, y=7.6502), Point(x=7.9546, y=7.7668), Point(x=6.9001, y=7.7668)]'
# ......Word '7,583,440,247' has a confidence of 0.991
# ......Word 'shares' has a confidence of 0.995
# Selection mark is 'selected' within bounding polygon '[Point(x=0.2263, y=1.5961), Point(x=0.3489, y=1.5961), Point(x=0.3489, y=1.7188), Point(x=0.2263, y=1.7188)]' and has a confidence of 0.99
# Selection mark is 'unselected' within bounding polygon '[Point(x=0.2304, y=2.2923), Point(x=0.3503, y=2.2923), Point(x=0.3503, y=2.411), Point(x=0.2304, y=2.411)]' and has a confidence of 0.977
# Selection mark is 'selected' within bounding polygon '[Point(x=0.7164, y=5.4787), Point(x=0.8027, y=5.4787), Point(x=0.8027, y=5.5637), Point(x=0.7164, y=5.5637)]' and has a confidence of 0.993
# Selection mark is 'unselected' within bounding polygon '[Point(x=1.0108, y=5.4801), Point(x=1.0957, y=5.4801), Point(x=1.0957, y=5.5651), Point(x=1.0108, y=5.5651)]' and has a confidence of 0.98
# Selection mark is 'selected' within bounding polygon '[Point(x=6.8185, y=5.7734), Point(x=6.9047, y=5.7734), Point(x=6.9047, y=5.8598), Point(x=6.8185, y=5.8598)]' and has a confidence of 0.995
# Selection mark is 'unselected' within bounding polygon '[Point(x=7.1115, y=5.7734), Point(x=7.1977, y=5.7734), Point(x=7.1977, y=5.8584), Point(x=7.1115, y=5.8584)]' and has a confidence of 0.993
# Selection mark is 'selected' within bounding polygon '[Point(x=1.2876, y=6.3278), Point(x=1.3711, y=6.3278), Point(x=1.3711, y=6.4114), Point(x=1.2876, y=6.4114)]' and has a confidence of 0.99
# Selection mark is 'unselected' within bounding polygon '[Point(x=6.809, y=6.3264), Point(x=6.8939, y=6.3264), Point(x=6.8939, y=6.41), Point(x=6.809, y=6.41)]' and has a confidence of 0.983
# Selection mark is 'unselected' within bounding polygon '[Point(x=1.2188, y=6.4913), Point(x=1.305, y=6.4913), Point(x=1.305, y=6.5763), Point(x=1.2188, y=6.5763)]' and has a confidence of 0.992
# Selection mark is 'unselected' within bounding polygon '[Point(x=7.3059, y=6.4927), Point(x=7.3935, y=6.4927), Point(x=7.3935, y=6.579), Point(x=7.3059, y=6.579)]' and has a confidence of 0.992
# Selection mark is 'unselected' within bounding polygon '[Point(x=7.3005, y=6.613), Point(x=7.3868, y=6.613), Point(x=7.3868, y=6.698), Point(x=7.3005, y=6.698)]' and has a confidence of 0.993
# Selection mark is 'unselected' within bounding polygon '[Point(x=4.2772, y=6.9496), Point(x=4.3634, y=6.9496), Point(x=4.3634, y=7.0359), Point(x=4.2772, y=7.0359)]' and has a confidence of 0.982
# Selection mark is 'unselected' within bounding polygon '[Point(x=5.7004, y=7.1416), Point(x=5.7866, y=7.1416), Point(x=5.7866, y=7.2266), Point(x=5.7004, y=7.2266)]' and has a confidence of 0.995
# Selection mark is 'selected' within bounding polygon '[Point(x=6.2635, y=7.1416), Point(x=6.3524, y=7.1416), Point(x=6.3524, y=7.2279), Point(x=6.2635, y=7.2279)]' and has a confidence of 0.993
# ----Analyzing layout from page #2----
# Page has width: 8.2639 and height: 11.6806, measured with unit: inch
# ...Line # 0 has word count 2 and text 'MICROSOFT CORPORATION' within bounding polygon '[Point(x=3.2447, y=0.2383), Point(x=4.9888, y=0.2383), Point(x=4.9888, y=0.3904), Point(x=3.2447, y=0.3904)]'
# ......Word 'MICROSOFT' has a confidence of 0.992
# ......Word 'CORPORATION' has a confidence of 0.993
# ...Line # 1 has word count 2 and text 'FORM 10-Q' within bounding polygon '[Point(x=3.7618, y=0.436), Point(x=4.4666, y=0.436), Point(x=4.4666, y=0.5729), Point(x=3.7618, y=0.5678)]'
# ......Word 'FORM' has a confidence of 0.993
# ......Word '10-Q' has a confidence of 0.993
# ...Line # 2 has word count 7 and text 'For the Quarter Ended March 31, 2020' within bounding polygon '[Point(x=2.9862, y=0.6286), Point(x=5.2524, y=0.6236), Point(x=5.2524, y=0.7757), Point(x=2.9862, y=0.7807)]'
# ......Word 'For' has a confidence of 0.997
# ......Word 'the' has a confidence of 0.997
# ......Word 'Quarter' has a confidence of 0.994
# ......Word 'Ended' has a confidence of 0.995
# ......Word 'March' has a confidence of 0.995
# ......Word '31,' has a confidence of 0.963
# ......Word '2020' has a confidence of 0.992
# ...Line # 3 has word count 1 and text 'INDEX' within bounding polygon '[Point(x=3.9241, y=0.8264), Point(x=4.3145, y=0.8264), Point(x=4.3094, y=0.9582), Point(x=3.9241, y=0.9531)]'
# ......Word 'INDEX' has a confidence of 0.995
# ...Line # 4 has word count 2 and text 'PART I.' within bounding polygon '[Point(x=0.2028, y=1.2421), Point(x=0.8112, y=1.2421), Point(x=0.8112, y=1.3891), Point(x=0.2028, y=1.3891)]'
# ......Word 'PART' has a confidence of 0.991
# ......Word 'I.' has a confidence of 0.972
# ...Line # 5 has word count 2 and text 'FINANCIAL INFORMATION' within bounding polygon '[Point(x=0.8365, y=1.2218), Point(x=2.4437, y=1.2218), Point(x=2.4437, y=1.3992), Point(x=0.8365, y=1.3992)]'
# ......Word 'FINANCIAL' has a confidence of 0.99
# ......Word 'INFORMATION' has a confidence of 0.992
# ...Line # 6 has word count 1 and text 'Page' within bounding polygon '[Point(x=7.7924, y=1.1204), Point(x=8.0307, y=1.1255), Point(x=8.0256, y=1.2218), Point(x=7.7924, y=1.2218)]'
# ......Word 'Page' has a confidence of 0.991
# ...Line # 7 has word count 2 and text 'Item 1.' within bounding polygon '[Point(x=0.8365, y=1.5868), Point(x=1.237, y=1.5868), Point(x=1.237, y=1.7136), Point(x=0.8365, y=1.7186)]'
# ......Word 'Item' has a confidence of 0.915
# ......Word '1.' has a confidence of 0.991
# ...Line # 8 has word count 2 and text 'Financial Statements' within bounding polygon '[Point(x=1.521, y=1.5767), Point(x=2.7124, y=1.5817), Point(x=2.7124, y=1.7237), Point(x=1.521, y=1.7186)]'
# ......Word 'Financial' has a confidence of 0.99
# ......Word 'Statements' has a confidence of 0.992
# ...Line # 9 has word count 15 and text 'a) Income Statements for the Three and Nine Months Ended March 31, 2020 and 2019' within bounding polygon '[Point(x=1.5311, y=1.8859), Point(x=6.4286, y=1.8859), Point(x=6.4286, y=2.0329), Point(x=1.5311, y=2.038)]'
# ......Word 'a)' has a confidence of 0.994
# ......Word 'Income' has a confidence of 0.993
# ......Word 'Statements' has a confidence of 0.992
# ......Word 'for' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.995
# ......Word 'Three' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.995
# ......Word 'Nine' has a confidence of 0.992
# ......Word 'Months' has a confidence of 0.993
# ......Word 'Ended' has a confidence of 0.995
# ......Word 'March' has a confidence of 0.995
# ......Word '31,' has a confidence of 0.995
# ......Word '2020' has a confidence of 0.992
# ......Word 'and' has a confidence of 0.994
# ......Word '2019' has a confidence of 0.987
# ...Line # 10 has word count 1 and text '3' within bounding polygon '[Point(x=7.9445, y=1.8961), Point(x=8.0205, y=1.8961), Point(x=8.0256, y=2.0177), Point(x=7.9496, y=2.0127)]'
# ......Word '3' has a confidence of 0.997
# ...Line # 11 has word count 16 and text 'b) Comprehensive Income Statements for the Three and Nine Months Ended March 31, 2020 and 2019' within bounding polygon '[Point(x=1.526, y=2.2256), Point(x=7.3412, y=2.2256), Point(x=7.3412, y=2.3726), Point(x=1.526, y=2.3777)]'
# ......Word 'b)' has a confidence of 0.995
# ......Word 'Comprehensive' has a confidence of 0.972
# ......Word 'Income' has a confidence of 0.985
# ......Word 'Statements' has a confidence of 0.983
# ......Word 'for' has a confidence of 0.995
# ......Word 'the' has a confidence of 0.996
# ......Word 'Three' has a confidence of 0.991
# ......Word 'and' has a confidence of 0.996
# ......Word 'Nine' has a confidence of 0.992
# ......Word 'Months' has a confidence of 0.995
# ......Word 'Ended' has a confidence of 0.995
# ......Word 'March' has a confidence of 0.989
# ......Word '31,' has a confidence of 0.92
# ......Word '2020' has a confidence of 0.991
# ......Word 'and' has a confidence of 0.996
# ......Word '2019' has a confidence of 0.992
# ...Line # 12 has word count 1 and text '4' within bounding polygon '[Point(x=7.9445, y=2.2357), Point(x=8.0256, y=2.2357), Point(x=8.0256, y=2.3523), Point(x=7.9445, y=2.3523)]'
# ......Word '4' has a confidence of 0.997
# ...Line # 13 has word count 12 and text 'c) Balance Sheets as of March 31, 2020 and June 30, 2019' within bounding polygon '[Point(x=1.526, y=2.5602), Point(x=4.9178, y=2.5602), Point(x=4.9178, y=2.7123), Point(x=1.526, y=2.7174)]'
# ......Word 'c)' has a confidence of 0.995
# ......Word 'Balance' has a confidence of 0.993
# ......Word 'Sheets' has a confidence of 0.994
# ......Word 'as' has a confidence of 0.996
# ......Word 'of' has a confidence of 0.996
# ......Word 'March' has a confidence of 0.995
# ......Word '31,' has a confidence of 0.988
# ......Word '2020' has a confidence of 0.992
# ......Word 'and' has a confidence of 0.961
# ......Word 'June' has a confidence of 0.993
# ......Word '30,' has a confidence of 0.995
# ......Word '2019' has a confidence of 0.983
# ...Line # 14 has word count 1 and text '5' within bounding polygon '[Point(x=7.9546, y=2.5754), Point(x=8.0307, y=2.5754), Point(x=8.0307, y=2.6819), Point(x=7.9546, y=2.6819)]'
# ......Word '5' has a confidence of 0.995
# ...Line # 15 has word count 16 and text 'e) Stockholders' Equity Statements for the Three and Nine Months Ended March 31, 2020 and 2019' within bounding polygon '[Point(x=1.521, y=3.2345), Point(x=7.1536, y=3.2345), Point(x=7.1536, y=3.3866), Point(x=1.521, y=3.3916)]'
# ......Word 'e)' has a confidence of 0.995
# ......Word 'Stockholders'' has a confidence of 0.974
# ......Word 'Equity' has a confidence of 0.977
# ......Word 'Statements' has a confidence of 0.992
# ......Word 'for' has a confidence of 0.996
# ......Word 'the' has a confidence of 0.996
# ......Word 'Three' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.995
# ......Word 'Nine' has a confidence of 0.993
# ......Word 'Months' has a confidence of 0.995
# ......Word 'Ended' has a confidence of 0.993
# ......Word 'March' has a confidence of 0.995
# ......Word '31,' has a confidence of 0.995
# ......Word '2020' has a confidence of 0.992
# ......Word 'and' has a confidence of 0.997
# ......Word '2019' has a confidence of 0.992
# ...Line # 16 has word count 1 and text 'f)' within bounding polygon '[Point(x=1.5362, y=3.5792), Point(x=1.7339, y=3.5792), Point(x=1.7339, y=3.7364), Point(x=1.5362, y=3.7211)]'
# ......Word 'f)' has a confidence of 0.918
# ...Line # 17 has word count 4 and text 'Notes to Financial Statements' within bounding polygon '[Point(x=1.7339, y=3.5792), Point(x=3.4374, y=3.5792), Point(x=3.4374, y=3.7262), Point(x=1.7339, y=3.7211)]'
# ......Word 'Notes' has a confidence of 0.994
# ......Word 'to' has a confidence of 0.996
# ......Word 'Financial' has a confidence of 0.993
# ......Word 'Statements' has a confidence of 0.993
# ...Line # 18 has word count 1 and text '8' within bounding polygon '[Point(x=7.9445, y=3.5893), Point(x=8.0155, y=3.5893), Point(x=8.0155, y=3.6958), Point(x=7.9496, y=3.6958)]'
# ......Word '8' has a confidence of 0.995
# ...Line # 19 has word count 8 and text 'g) Report of Independent Registered Public Accounting Firm' within bounding polygon '[Point(x=1.521, y=3.9138), Point(x=4.9634, y=3.9087), Point(x=4.9685, y=4.0608), Point(x=1.526, y=4.071)]'
# ......Word 'g)' has a confidence of 0.993
# ......Word 'Report' has a confidence of 0.995
# ......Word 'of' has a confidence of 0.992
# ......Word 'Independent' has a confidence of 0.97
# ......Word 'Registered' has a confidence of 0.992
# ......Word 'Public' has a confidence of 0.936
# ......Word 'Accounting' has a confidence of 0.992
# ......Word 'Firm' has a confidence of 0.992
# ...Line # 20 has word count 1 and text '30' within bounding polygon '[Point(x=7.8786, y=3.9239), Point(x=8.0155, y=3.9189), Point(x=8.0205, y=4.0405), Point(x=7.8836, y=4.0405)]'
# ......Word '30' has a confidence of 0.998
# ...Line # 21 has word count 1 and text '6' within bounding polygon '[Point(x=7.9445, y=2.91), Point(x=8.0256, y=2.91), Point(x=8.0256, y=3.0266), Point(x=7.9496, y=3.0215)]'
# ......Word '6' has a confidence of 0.995
# ...Line # 22 has word count 16 and text 'd) Cash Flows Statements for the Three and Nine Months Ended March 31, 2020 and 2019' within bounding polygon '[Point(x=1.521, y=2.9049), Point(x=6.677, y=2.8948), Point(x=6.677, y=3.0418), Point(x=1.521, y=3.052)]'
# ......Word 'd)' has a confidence of 0.993
# ......Word 'Cash' has a confidence of 0.993
# ......Word 'Flows' has a confidence of 0.992
# ......Word 'Statements' has a confidence of 0.99
# ......Word 'for' has a confidence of 0.947
# ......Word 'the' has a confidence of 0.995
# ......Word 'Three' has a confidence of 0.995
# ......Word 'and' has a confidence of 0.995
# ......Word 'Nine' has a confidence of 0.99
# ......Word 'Months' has a confidence of 0.993
# ......Word 'Ended' has a confidence of 0.995
# ......Word 'March' has a confidence of 0.995
# ......Word '31,' has a confidence of 0.961
# ......Word '2020' has a confidence of 0.991
# ......Word 'and' has a confidence of 0.996
# ......Word '2019' has a confidence of 0.983
# ...Line # 23 has word count 1 and text '7' within bounding polygon '[Point(x=7.9546, y=3.2497), Point(x=8.0155, y=3.2497), Point(x=8.0155, y=3.3612), Point(x=7.9546, y=3.3561)]'
# ......Word '7' has a confidence of 0.995
# ...Line # 24 has word count 2 and text 'Item 2.' within bounding polygon '[Point(x=0.8315, y=4.2281), Point(x=1.2218, y=4.2281), Point(x=1.2218, y=4.3549), Point(x=0.8315, y=4.3549)]'
# ......Word 'Item' has a confidence of 0.915
# ......Word '2.' has a confidence of 0.995
# ...Line # 25 has word count 11 and text 'Management's Discussion and Analysis of Financial Condition and Results of Operations' within bounding polygon '[Point(x=1.521, y=4.218), Point(x=6.4692, y=4.218), Point(x=6.4692, y=4.3751), Point(x=1.521, y=4.3751)]'
# ......Word 'Management's' has a confidence of 0.993
# ......Word 'Discussion' has a confidence of 0.993
# ......Word 'and' has a confidence of 0.992
# ......Word 'Analysis' has a confidence of 0.968
# ......Word 'of' has a confidence of 0.995
# ......Word 'Financial' has a confidence of 0.993
# ......Word 'Condition' has a confidence of 0.991
# ......Word 'and' has a confidence of 0.994
# ......Word 'Results' has a confidence of 0.993
# ......Word 'of' has a confidence of 0.994
# ......Word 'Operations' has a confidence of 0.993
# ...Line # 26 has word count 1 and text '31' within bounding polygon '[Point(x=7.8786, y=4.2332), Point(x=8.0003, y=4.2281), Point(x=8.0053, y=4.3498), Point(x=7.8786, y=4.3498)]'
# ......Word '31' has a confidence of 0.995
# ...Line # 27 has word count 2 and text 'Item 3.' within bounding polygon '[Point(x=0.8264, y=4.5374), Point(x=1.2269, y=4.5374), Point(x=1.2269, y=4.6641), Point(x=0.8264, y=4.6641)]'
# ......Word 'Item' has a confidence of 0.93
# ......Word '3.' has a confidence of 0.995
# ...Line # 28 has word count 7 and text 'Quantitative and Qualitative Disclosures About Market Risk' within bounding polygon '[Point(x=1.5159, y=4.5272), Point(x=4.8214, y=4.5272), Point(x=4.8214, y=4.6743), Point(x=1.5159, y=4.6743)]'
# ......Word 'Quantitative' has a confidence of 0.993
# ......Word 'and' has a confidence of 0.993
# ......Word 'Qualitative' has a confidence of 0.993
# ......Word 'Disclosures' has a confidence of 0.993
# ......Word 'About' has a confidence of 0.993
# ......Word 'Market' has a confidence of 0.994
# ......Word 'Risk' has a confidence of 0.992
# ...
# ...Cell[6][3] has text '3,940'
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=1.7034), Point(x=7.058, y=1.7034), Point(x=7.058, y=1.8406), Point(x=6.0977, y=1.8406)]'
# ...Cell[6][4] has text '3,462'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=1.7034), Point(x=8.0345, y=1.7034), Point(x=8.0345, y=1.8406), Point(x=7.058, y=1.8406)]'
# ...Cell[7][0] has text 'Other, net'
# ...content on page 7 is within bounding polygon '[Point(x=0.2064, y=1.8487), Point(x=3.6766, y=1.8406), Point(x=3.6766, y=2.0182), Point(x=0.2064, y=2.0182)]'
# ...Cell[7][1] has text '0'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=1.8406), Point(x=5.1777, y=1.8406), Point(x=5.1777, y=2.0182), Point(x=3.6766, y=2.0182)]'
# ...Cell[7][2] has text '7'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=1.8406), Point(x=6.0977, y=1.8406), Point(x=6.0977, y=2.0182), Point(x=5.1777, y=2.0182)]'
# ...Cell[7][3] has text '(1)'
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=1.8406), Point(x=7.058, y=1.8406), Point(x=7.058, y=2.0182), Point(x=6.0977, y=2.0182)]'
# ...Cell[7][4] has text '18'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=1.8406), Point(x=8.0345, y=1.8406), Point(x=8.0345, y=2.0182), Point(x=7.058, y=2.0182)]'
# ...Cell[8][0] has text 'Balance, end of period'
# ...content on page 7 is within bounding polygon '[Point(x=0.2064, y=2.0182), Point(x=3.6766, y=2.0182), Point(x=3.6766, y=2.2442), Point(x=0.2064, y=2.2442)]'
# ...Cell[8][1] has text '79,813'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=2.0182), Point(x=5.1777, y=2.0182), Point(x=5.1777, y=2.2442), Point(x=3.6766, y=2.2442)]'
# ...Cell[8][2] has text '77,791'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=2.0182), Point(x=6.0977, y=2.0182), Point(x=6.0977, y=2.2442), Point(x=5.1777, y=2.2442)]'
# ...Cell[8][3] has text '79,813'
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=2.0182), Point(x=7.058, y=2.0182), Point(x=7.058, y=2.2442), Point(x=6.0977, y=2.2442)]'
# ...Cell[8][4] has text '77,791'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=2.0182), Point(x=8.0345, y=2.0182), Point(x=8.0345, y=2.2442), Point(x=7.058, y=2.2442)]'
# ...Cell[9][0] has text 'Retained earnings'
# ...content on page 7 is within bounding polygon '[Point(x=0.2064, y=2.2442), Point(x=3.6766, y=2.2442), Point(x=3.6766, y=2.438), Point(x=0.2064, y=2.438)]'
# ...Cell[9][1] has text ''
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=2.2442), Point(x=5.1777, y=2.2442), Point(x=5.1777, y=2.4299), Point(x=3.6766, y=2.438)]'
# ...Cell[9][2] has text ''
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=2.2442), Point(x=6.0977, y=2.2442), Point(x=6.0977, y=2.4299), Point(x=5.1777, y=2.4299)]'
# ...Cell[9][3] has text ''
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=2.2442), Point(x=7.058, y=2.2442), Point(x=7.058, y=2.4299), Point(x=6.0977, y=2.4299)]'
# ...Cell[9][4] has text ''
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=2.2442), Point(x=8.0345, y=2.2442), Point(x=8.0345, y=2.4299), Point(x=7.058, y=2.4299)]'
# ...Cell[10][0] has text 'Balance, beginning of period'
# ...content on page 7 is within bounding polygon '[Point(x=0.2064, y=2.438), Point(x=3.6766, y=2.438), Point(x=3.6766, y=2.5672), Point(x=0.2064, y=2.5672)]'
# ...Cell[10][1] has text '30,739'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=2.438), Point(x=5.1777, y=2.4299), Point(x=5.1777, y=2.5672), Point(x=3.6766, y=2.5672)]'
# ...Cell[10][2] has text '16,585'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=2.4299), Point(x=6.0977, y=2.4299), Point(x=6.0977, y=2.5672), Point(x=5.1777, y=2.5672)]'
# ...Cell[10][3] has text '24,150'
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=2.4299), Point(x=7.058, y=2.4299), Point(x=7.058, y=2.5672), Point(x=6.0977, y=2.5672)]'
# ...Cell[10][4] has text '13,682'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=2.4299), Point(x=8.0345, y=2.4299), Point(x=8.0345, y=2.5672), Point(x=7.058, y=2.5672)]'
# ...Cell[11][0] has text 'Net income'
# ...content on page 7 is within bounding polygon '[Point(x=0.2064, y=2.5672), Point(x=3.6766, y=2.5672), Point(x=3.6766, y=2.6963), Point(x=0.2064, y=2.6963)]'
# ...Cell[11][1] has text '10,752'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=2.5672), Point(x=5.1777, y=2.5672), Point(x=5.1777, y=2.6963), Point(x=3.6766, y=2.6963)]'
# ...Cell[11][2] has text '8,809'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=2.5672), Point(x=6.0977, y=2.5672), Point(x=6.0977, y=2.6963), Point(x=5.1777, y=2.6963)]'
# ...Cell[11][3] has text '33,079'
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=2.5672), Point(x=7.058, y=2.5672), Point(x=7.058, y=2.6963), Point(x=6.0977, y=2.6963)]'
# ...Cell[11][4] has text '26,053'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=2.5672), Point(x=8.0345, y=2.5672), Point(x=8.0345, y=2.6963), Point(x=7.058, y=2.6963)]'
# ...Cell[12][0] has text 'Common stock cash dividends'
# ...content on page 7 is within bounding polygon '[Point(x=0.2064, y=2.6963), Point(x=3.6766, y=2.6963), Point(x=3.6766, y=2.8335), Point(x=0.2064, y=2.8335)]'
# ...Cell[12][1] has text '(3,865)'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=2.6963), Point(x=5.1777, y=2.6963), Point(x=5.1777, y=2.8255), Point(x=3.6766, y=2.8335)]'
# ...Cell[12][2] has text '(3,518)'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=2.6963), Point(x=6.0977, y=2.6963), Point(x=6.0977, y=2.8255), Point(x=5.1777, y=2.8255)]'
# ...Cell[12][3] has text '(11,627)'
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=2.6963), Point(x=7.058, y=2.6963), Point(x=7.058, y=2.8255), Point(x=6.0977, y=2.8255)]'
# ...Cell[12][4] has text '(10,592)'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=2.6963), Point(x=8.0345, y=2.6963), Point(x=8.0345, y=2.8255), Point(x=7.058, y=2.8255)]'
# ...Cell[13][0] has text 'Common stock repurchased'
# ...content on page 7 is within bounding polygon '[Point(x=0.2064, y=2.8335), Point(x=3.6766, y=2.8335), Point(x=3.6766, y=2.9546), Point(x=0.2064, y=2.9546)]'
# ...Cell[13][1] has text '(5,614)'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=2.8335), Point(x=5.1777, y=2.8255), Point(x=5.1777, y=2.9546), Point(x=3.6766, y=2.9546)]'
# ...Cell[13][2] has text '(3,538)'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=2.8255), Point(x=6.0977, y=2.8255), Point(x=6.0977, y=2.9546), Point(x=5.1777, y=2.9546)]'
# ...Cell[13][3] has text '(13,590)'
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=2.8255), Point(x=7.058, y=2.8255), Point(x=7.058, y=2.9546), Point(x=6.0977, y=2.9546)]'
# ...Cell[13][4] has text '(11,482)'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=2.8255), Point(x=8.0345, y=2.8255), Point(x=8.0345, y=2.9546), Point(x=7.058, y=2.9546)]'
# ...Cell[14][0] has text 'Cumulative effect of accounting changes'
# ...content on page 7 is within bounding polygon '[Point(x=0.2064, y=2.9546), Point(x=3.6766, y=2.9546), Point(x=3.6766, y=3.1403), Point(x=0.2064, y=3.1403)]'
# ...Cell[14][1] has text '0'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=2.9546), Point(x=5.1777, y=2.9546), Point(x=5.1777, y=3.1403), Point(x=3.6766, y=3.1403)]'
# ...Cell[14][2] has text '0'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=2.9546), Point(x=6.0977, y=2.9546), Point(x=6.0977, y=3.1403), Point(x=5.1777, y=3.1403)]'
# ...Cell[14][3] has text '0'
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=2.9546), Point(x=7.058, y=2.9546), Point(x=7.058, y=3.1403), Point(x=6.0977, y=3.1403)]'
# ...Cell[14][4] has text '677'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=2.9546), Point(x=8.0345, y=2.9546), Point(x=8.0345, y=3.1403), Point(x=7.058, y=3.1403)]'
# ...Cell[15][0] has text 'Balance, end of period'
# ...content on page 7 is within bounding polygon '[Point(x=0.2064, y=3.1403), Point(x=3.6766, y=3.1403), Point(x=3.6766, y=3.3825), Point(x=0.2064, y=3.3825)]'
# ...Cell[15][1] has text '32,012'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=3.1403), Point(x=5.1777, y=3.1403), Point(x=5.1777, y=3.3825), Point(x=3.6766, y=3.3825)]'
# ...Cell[15][2] has text '18,338'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=3.1403), Point(x=6.0977, y=3.1403), Point(x=6.0977, y=3.3825), Point(x=5.1777, y=3.3825)]'
# ...Cell[15][3] has text '32,012'
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=3.1403), Point(x=7.058, y=3.1403), Point(x=7.058, y=3.3825), Point(x=6.0977, y=3.3825)]'
# ...Cell[15][4] has text '18,338'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=3.1403), Point(x=8.0345, y=3.1403), Point(x=8.0345, y=3.3825), Point(x=7.058, y=3.3825)]'
# ...Cell[16][0] has text 'Accumulated other comprehensive income (loss)'
# ...content on page 7 is within bounding polygon '[Point(x=0.2064, y=3.3825), Point(x=3.6766, y=3.3825), Point(x=3.6766, y=3.5601), Point(x=0.1983, y=3.5682)]'
# ...Cell[16][1] has text ''
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=3.3825), Point(x=5.1777, y=3.3825), Point(x=5.1777, y=3.5601), Point(x=3.6766, y=3.5601)]'
# ...Cell[16][2] has text ''
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=3.3825), Point(x=6.0977, y=3.3825), Point(x=6.0977, y=3.5601), Point(x=5.1777, y=3.5601)]'
# ...Cell[16][3] has text ''
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=3.3825), Point(x=7.058, y=3.3825), Point(x=7.058, y=3.5601), Point(x=6.0977, y=3.5601)]'
# ...Cell[16][4] has text ''
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=3.3825), Point(x=8.0345, y=3.3825), Point(x=8.0345, y=3.5601), Point(x=7.058, y=3.5601)]'
# ...Cell[17][0] has text 'Balance, beginning of period'
# ...content on page 7 is within bounding polygon '[Point(x=0.1983, y=3.5682), Point(x=3.6766, y=3.5601), Point(x=3.6766, y=3.6973), Point(x=0.1983, y=3.6973)]'
# ...Cell[17][1] has text '(255)'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=3.5601), Point(x=5.1777, y=3.5601), Point(x=5.1777, y=3.6973), Point(x=3.6766, y=3.6973)]'
# ...Cell[17][2] has text '(2,013)'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=3.5601), Point(x=6.0977, y=3.5601), Point(x=6.0977, y=3.6973), Point(x=5.1777, y=3.6973)]'
# ...Cell[17][3] has text '(340)'
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=3.5601), Point(x=7.058, y=3.5601), Point(x=7.058, y=3.6973), Point(x=6.0977, y=3.6973)]'
# ...Cell[17][4] has text '(2,187)'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=3.5601), Point(x=8.0345, y=3.5601), Point(x=8.0345, y=3.6973), Point(x=7.058, y=3.6973)]'
# ...Cell[18][0] has text 'Other comprehensive income'
# ...content on page 7 is within bounding polygon '[Point(x=0.1983, y=3.6973), Point(x=3.6766, y=3.6973), Point(x=3.6766, y=3.8265), Point(x=0.1983, y=3.8265)]'
# ...Cell[18][1] has text '2,931'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=3.6973), Point(x=5.1777, y=3.6973), Point(x=5.1777, y=3.8265), Point(x=3.6766, y=3.8265)]'
# ...Cell[18][2] has text '748'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=3.6973), Point(x=6.0977, y=3.6973), Point(x=6.0896, y=3.8265), Point(x=5.1777, y=3.8265)]'
# ...Cell[18][3] has text '3,016'
# ...content on page 7 is within bounding polygon '[Point(x=6.0977, y=3.6973), Point(x=7.058, y=3.6973), Point(x=7.058, y=3.8265), Point(x=6.0896, y=3.8265)]'
# ...Cell[18][4] has text '989'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=3.6973), Point(x=8.0345, y=3.6973), Point(x=8.0345, y=3.8265), Point(x=7.058, y=3.8265)]'
# ...Cell[19][0] has text 'Cumulative effect of accounting changes'
# ...content on page 7 is within bounding polygon '[Point(x=0.1983, y=3.8265), Point(x=3.6766, y=3.8265), Point(x=3.6766, y=4.0041), Point(x=0.1983, y=4.0041)]'
# ...Cell[19][1] has text '0'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=3.8265), Point(x=5.1777, y=3.8265), Point(x=5.1777, y=4.0041), Point(x=3.6766, y=4.0041)]'
# ...Cell[19][2] has text '0'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=3.8265), Point(x=6.0896, y=3.8265), Point(x=6.0896, y=4.0041), Point(x=5.1777, y=4.0041)]'
# ...Cell[19][3] has text '0'
# ...content on page 7 is within bounding polygon '[Point(x=6.0896, y=3.8265), Point(x=7.058, y=3.8265), Point(x=7.058, y=4.0041), Point(x=6.0896, y=4.0041)]'
# ...Cell[19][4] has text '(67)'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=3.8265), Point(x=8.0345, y=3.8265), Point(x=8.0345, y=4.0041), Point(x=7.058, y=4.0041)]'
# ...Cell[20][0] has text 'Balance, end of period'
# ...content on page 7 is within bounding polygon '[Point(x=0.1983, y=4.0041), Point(x=3.6766, y=4.0041), Point(x=3.6766, y=4.2382), Point(x=0.1983, y=4.2382)]'
# ...Cell[20][1] has text '2,676'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=4.0041), Point(x=5.1777, y=4.0041), Point(x=5.1777, y=4.2382), Point(x=3.6766, y=4.2382)]'
# ...Cell[20][2] has text '(1,265)'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=4.0041), Point(x=6.0896, y=4.0041), Point(x=6.0896, y=4.2382), Point(x=5.1777, y=4.2382)]'
# ...Cell[20][3] has text '2,676'
# ...content on page 7 is within bounding polygon '[Point(x=6.0896, y=4.0041), Point(x=7.058, y=4.0041), Point(x=7.058, y=4.2382), Point(x=6.0896, y=4.2382)]'
# ...Cell[20][4] has text '(1,265)'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=4.0041), Point(x=8.0345, y=4.0041), Point(x=8.0345, y=4.2382), Point(x=7.058, y=4.2382)]'
# ...Cell[21][0] has text 'Total stockholders' equity'
# ...content on page 7 is within bounding polygon '[Point(x=0.1983, y=4.2382), Point(x=3.6766, y=4.2382), Point(x=3.6766, y=4.5126), Point(x=0.1983, y=4.5126)]'
# ...Cell[21][1] has text '$ 114,501'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=4.2382), Point(x=5.1777, y=4.2382), Point(x=5.1777, y=4.5046), Point(x=3.6766, y=4.5126)]'
# ...Cell[21][2] has text '$ 94,864'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=4.2382), Point(x=6.0896, y=4.2382), Point(x=6.0896, y=4.5046), Point(x=5.1777, y=4.5046)]'
# ...Cell[21][3] has text '$ 114,501'
# ...content on page 7 is within bounding polygon '[Point(x=6.0896, y=4.2382), Point(x=7.058, y=4.2382), Point(x=7.058, y=4.5046), Point(x=6.0896, y=4.5046)]'
# ...Cell[21][4] has text '$ 94,864'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=4.2382), Point(x=8.0345, y=4.2382), Point(x=8.0345, y=4.5046), Point(x=7.058, y=4.5046)]'
# ...Cell[22][0] has text 'Cash dividends declared per common share'
# ...content on page 7 is within bounding polygon '[Point(x=0.1983, y=4.5126), Point(x=3.6766, y=4.5126), Point(x=3.6685, y=4.7064), Point(x=0.1983, y=4.7064)]'
# ...Cell[22][1] has text '$ 0.51'
# ...content on page 7 is within bounding polygon '[Point(x=3.6766, y=4.5126), Point(x=5.1777, y=4.5046), Point(x=5.1777, y=4.7064), Point(x=3.6685, y=4.7064)]'
# ...Cell[22][2] has text '$ 0.46'
# ...content on page 7 is within bounding polygon '[Point(x=5.1777, y=4.5046), Point(x=6.0896, y=4.5046), Point(x=6.0896, y=4.7064), Point(x=5.1777, y=4.7064)]'
# ...Cell[22][3] has text '$ 1.53'
# ...content on page 7 is within bounding polygon '[Point(x=6.0896, y=4.5046), Point(x=7.058, y=4.5046), Point(x=7.058, y=4.7064), Point(x=6.0896, y=4.7064)]'
# ...Cell[22][4] has text '$ 1.38'
# ...content on page 7 is within bounding polygon '[Point(x=7.058, y=4.5046), Point(x=8.0345, y=4.5046), Point(x=8.0345, y=4.7064), Point(x=7.058, y=4.7064)]'

# %% [markdown]
# ## C. Extracted Layout Document insights/ response as a JSON format

# %%
# import JSON packages
import json
import datetime
import time
from azure.core.serialization import AzureJSONEncoder
from urllib.parse import urlparse


# generate the unique file name
filename = datetime.datetime.fromtimestamp(time.time()).strftime('%Y%m%d%H%M%S')+"_"+os.path.splitext(os.path.basename(urlparse(layoutUrl).path))[0]

# parse and format the model response json 
# convert the received model to a dictionary
analyze_result_dict = result.to_dict()

# save the dictionary as JSON content in a JSON file, use the AzureJSONEncoder
# to help make types, such as dates, JSON serializable
with open(str(filename), 'w') as f:
        json.dump(analyze_result_dict, f, cls=AzureJSONEncoder,indent=4)

# convert the dictionary back to the original model
model = AnalyzeResult.from_dict(analyze_result_dict)
print("--------------JSON Response from Model Starts---------------------")
# use the model as normal
print("Model ID: '{}'".format(model.model_id))
print("Number of pages analyzed {}".format(len(model.pages)))
print("API version used: {}".format(model.api_version))
print(json.dumps(analyze_result_dict,cls=AzureJSONEncoder,indent=4))
print("--------------JSON Response from Model Ends---------------------")
# Out:
# --------------JSON Response from Model Starts---------------------
# Model ID: 'prebuilt-layout'
# Number of pages analyzed 10
# API version used: 2023-07-31
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ### **If we want to save it in JSON format**

# %%
import json
import datetime
import time
from azure.core.serialization import AzureJSONEncoder
from urllib.parse import urlparse

# Generate the unique file name
filename = datetime.datetime.fromtimestamp(time.time()).strftime('%Y%m%d%H%M%S') + "_" + os.path.splitext(os.path.basename(urlparse(layoutUrl).path))[0] + ".json"

# Parse and format the model response JSON 
analyze_result_dict = result.to_dict()

# Save the dictionary as JSON content in a JSON file, use the AzureJSONEncoder
# to help make types, such as dates, JSON serializable
with open(filename, 'w') as f:
    json.dump(analyze_result_dict, f, cls=AzureJSONEncoder, indent=4)

print("JSON response saved to file:", filename)
